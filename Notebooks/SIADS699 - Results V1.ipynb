# %% [markdown]
# University of Michigan
#
# Master of Applied Data Science
#
# SIADS699 - Capstone Project
#
# Andre Onofre, Samantha Roska, Sawsan Allam

# %% [markdown]
# This Notebook: Training Results

# %%
# Mount Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
# Import Libraries
import pandas as pd

# %%
# Directories
IMAGES_DIR = './Images/BCN20000-all-images-original/bcn_20k_train/'
META_DATA_DIR = './Metadata/'
MODELS_DIR = './Models/'
TEST_IMAGES_DIR = './Images/Images_for_tests/'
TRAINING_RESULTS_DIR = './Training_Results/'

# %%
## Smartphone Images ##

# %%
# Smartphone Images Training: No Weights, No Augmentation
df1 = pd.read_csv(TRAINING_RESULTS_DIR + 'PAD-UFES-20-V101-Training_Results.csv')
df1 = df1[['Model', 'Accuracy', 'F1', 'Acc_0', 'Acc_1','Acc_2', 'Acc_3', 'Acc_4', 'Acc_5', 'Acc_6', 'Balanced_Accuracy']]
df1

# %%
# Smartphone Images Training: With Weights
df2 = pd.read_csv(TRAINING_RESULTS_DIR + 'PAD-UFES-20-V102-Training_Results.csv')
df2 = df2[['Model', 'Accuracy', 'F1', 'Acc_0', 'Acc_1','Acc_2', 'Acc_3', 'Acc_4', 'Acc_5', 'Acc_6', 'Balanced_Accuracy']]
df2

# %%
# Smartphone Images Training: With Augmentation
df3 = pd.read_csv(TRAINING_RESULTS_DIR + 'PAD-UFES-20-V103-Training_Results.csv')
df3 = df3[['Model', 'Accuracy', 'F1', 'Acc_0', 'Acc_1','Acc_2', 'Acc_3', 'Acc_4', 'Acc_5', 'Acc_6', 'Balanced_Accuracy']]
df3

# %%
# Smartphone Images Training: With Weights + Augmentation
df4 = pd.read_csv(TRAINING_RESULTS_DIR + 'PAD-UFES-20-V104-Training_Results.csv')
df4 = df4[['Model', 'Accuracy', 'F1', 'Acc_0', 'Acc_1','Acc_2', 'Acc_3', 'Acc_4', 'Acc_5', 'Acc_6', 'Balanced_Accuracy']]
df4

# %%
## Dermatoscopic Images ##

# %%
# Dermatoscopic Images Training: No Weights, No Augmentation
df11 = pd.read_csv(TRAINING_RESULTS_DIR + 'BCN20000-V101-Training_Results.csv')
df11 = df11[['Model', 'Accuracy', 'Balanced_Accuracy', 'Acc_0', 'Acc_1','Acc_2', 'Acc_3', 'Acc_4', 'Acc_5', 'Acc_6', 'Acc_7', 'F1']]
df11

# %%
# Dermatoscopic Images Training: With Weights
df12 = pd.read_csv(TRAINING_RESULTS_DIR + 'BCN20000-V102-Training_Results.csv')
df12 = df12[['Model', 'Accuracy', 'Balanced_Accuracy', 'Acc_0', 'Acc_1','Acc_2', 'Acc_3', 'Acc_4', 'Acc_5', 'Acc_6', 'Acc_7', 'F1']]
df12

# %%
# Dermatoscopic Images Training: With Augmentation
df13 = pd.read_csv(TRAINING_RESULTS_DIR + 'BCN20000-V103-Training_Results.csv')
df13 = df13[['Model', 'Accuracy', 'Balanced_Accuracy', 'Acc_0', 'Acc_1','Acc_2', 'Acc_3', 'Acc_4', 'Acc_5', 'Acc_6', 'Acc_7', 'F1']]
df13

# %%
# Dermatoscopic Images Training: With Weights + Augmentation
df14 = pd.read_csv(TRAINING_RESULTS_DIR + 'BCN20000-V104-Training_Results.csv')
df14 = df14[['Model', 'Accuracy', 'Balanced_Accuracy', 'Acc_0', 'Acc_1','Acc_2', 'Acc_3', 'Acc_4', 'Acc_5', 'Acc_6', 'Acc_7', 'F1']]
df14
